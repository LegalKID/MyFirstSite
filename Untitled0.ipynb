# %% [markdown]
# <a href="https://colab.research.google.com/github/LegalKID/MyFirstSite/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3dcbc364-f287-436d-b2c3-7dc4c67336d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3dcbc364-f287-436d-b2c3-7dc4c67336d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

#cv2 = resim okuma kodu

image = cv2.imread("/content/teletabi.jpg")

#resim = şu dosyayı("/content/teletabi.jpg") oku

height, width, canals = image.shape

#print("Yükseklik: ",height)

#print("Genişlik: ",width)


cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>

# %%
# !pip install Pillow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.1 MB/s eta 0:00:00
# ...

# %%
from rembg import remove
import google.colab.patches

output_path = "arkaplansız.png"
input_path = "/content/teletabi.jpg"

with open(input_path, "rb") as i:
  with open(output_path, "wb") as o:
    input = i.read()
    output = remove(input)
    o.write(output)

    image_result = cv2.imread(output_path)

    cv2_imshow(image_result)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
